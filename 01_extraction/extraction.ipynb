# %%
import pandas as pd

# %%
url = "https://www.data.gouv.fr/fr/datasets/r/e455db41-28c2-419d-bdf1-d44635fdc97e"
df = pd.read_csv(url, sep=";")

# %%
# Afficher les premières lignes du jeu de données
print(df.head())
# Out:
#                                            operateur  annee      filiere  \
# 0          Centrale électrique Vonderscheer de Ville   2011  Electricité
# 1  Coopérative d'électricité de Saint Martin de L...   2011  Electricité
# 2                                             Enedis   2011  Electricité
# 3                                             Enedis   2011  Electricité
# 4                                             Enedis   2011  Electricité
#
#      consoa  pdla  nombre_maille_secretisees_a  indquala     consoi  pdli  \
# 0      0.00     0                            0     0.000     271.00     4
# 1   1414.68    22                            0     1.000   15865.01    66
# 2   6496.52    70                            0     0.934  510119.99   501
# 3  12493.80   127                            0     0.887  318256.95   575
# 4  62161.03  1231                            0     0.978  292151.22   791
#
#    nombre_maille_secretisees_i  ...  pdlna  nombre_maille_secretisees_na  \
# ...

# %% [markdown]
# Affichage du types des colonnes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5592 entries, 0 to 5591
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   operateur                     5592 non-null   object
#  1   annee                         5592 non-null   int64
#  2   filiere                       5592 non-null   object
#  3   consoa                        5592 non-null   float64
#  4   pdla                          5592 non-null   int64
#  5   nombre_maille_secretisees_a   5592 non-null   int64
#  6   indquala                      5592 non-null   float64
#  7   consoi                        5592 non-null   float64
#  8   pdli                          5592 non-null   int64
#  9   nombre_maille_secretisees_i   5592 non-null   int64
#  10  indquali                      5592 non-null   float64
#  11  consot                        5592 non-null   float64
# ...

# %%
print(df.dtypes)
# Out:
# operateur                        object
# annee                             int64
# filiere                          object
# consoa                          float64
# pdla                              int64
# nombre_maille_secretisees_a       int64
# indquala                        float64
# consoi                          float64
# pdli                              int64
# nombre_maille_secretisees_i       int64
# indquali                        float64
# consot                          float64
# pdlt                              int64
# nombre_maille_secretisees_t       int64
# indqualt                        float64
# consor                          float64
# pdlr                              int64
# nombre_maille_secretisees_r       int64
# indqualr                        float64
# consona                         float64
# pdlna                             int64
# nombre_maille_secretisees_na      int64
# indqualna                       float64
# ...

# %%
df.describe()
# Out:
#              annee         consoa         pdla  nombre_maille_secretisees_a  \
# count  5592.000000    5592.000000  5592.000000                  5592.000000
# mean   2016.338162   14512.841889   234.855508                    13.733727
# std       3.063144   42027.799249   881.042503                    51.224939
# min    2011.000000       0.000000     0.000000                     0.000000
# 25%    2014.000000       0.000000     0.000000                     0.000000
# 50%    2016.000000       0.000000     0.000000                     0.000000
# 75%    2019.000000    7973.537447    28.000000                     0.000000
# max    2021.000000  467701.000000  8590.000000                   462.000000
#
#           indquala        consoi          pdli  nombre_maille_secretisees_i  \
# count  5592.000000  5.592000e+03   5592.000000                  5592.000000
# mean      0.378793  6.710099e+05    428.995887                    17.119099
# ...
